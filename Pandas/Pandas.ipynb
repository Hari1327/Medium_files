# %% [markdown]
# # Series

# %%
import pandas as pd

df = pd.read_csv("matches.csv")
df
len(df.dtypes)
# Out:
# 18

# %%
df.head()
# Out:
#                    A         B         C         D
# ZqgszYBfuL  0.125730  0.345584  0.189053  2.040919
# YT9l2dIrmO -0.132105  0.821618 -0.522748 -2.555665
# sIqjUAQP6A  0.640423  0.330437 -0.413064  0.418099
# nN571Qxycl  0.104900 -1.303157 -2.441467 -0.567770
# uvJFQ32W8t -0.535669  0.905356  1.799707 -0.452649

# %%
df1 = pd._testing.makeDataFrame()
print(df1.shape)
df1.head()
# Out:
# (30, 4)
#                    A         B         C         D
# ZqgszYBfuL  0.125730  0.345584  0.189053  2.040919
# YT9l2dIrmO -0.132105  0.821618 -0.522748 -2.555665
# sIqjUAQP6A  0.640423  0.330437 -0.413064  0.418099
# nN571Qxycl  0.104900 -1.303157 -2.441467 -0.567770
# uvJFQ32W8t -0.535669  0.905356  1.799707 -0.452649

# %%
df.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.sample()
# Out:
#       id  season       city        date                team1  \
# 617  618    2016  Hyderabad  2016-05-12  Sunrisers Hyderabad
#
#                 team2       toss_winner toss_decision  result  dl_applied  \
# 617  Delhi Daredevils  Delhi Daredevils         field  normal           0
#
#                winner  win_by_runs  win_by_wickets player_of_match  \
# 617  Delhi Daredevils            0               7       CH Morris
#
#                                          venue     umpire1    umpire2  umpire3
# 617  Rajiv Gandhi International Stadium, Uppal  K Bharatan  M Erasmus      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
des = df.describe()

# %%
df.query('win_by_runs > 140')
# Out:
#       id  season       city        date                        team1  \
# 43    44    2017      Delhi  2017-05-06               Mumbai Indians
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
#
#                 team2       toss_winner toss_decision  result  dl_applied  \
# 43   Delhi Daredevils  Delhi Daredevils         field  normal           0
# 619     Gujarat Lions     Gujarat Lions         field  normal           0
#
#                           winner  win_by_runs  win_by_wickets player_of_match  \
# 43                Mumbai Indians          146               0     LMP Simmons
# 619  Royal Challengers Bangalore          144               0  AB de Villiers
#
#                      venue      umpire1    umpire2  umpire3
# 43        Feroz Shah Kotla  Nitin Menon  CK Nandan      NaN
# 619  M Chinnaswamy Stadium  AY Dandekar  VK Sharma      NaN

# %%
df.loc[632:]
# Out:
#       id  season       city        date                team1  \
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 632  normal           0  Royal Challengers Bangalore            0
# 633  normal           0          Sunrisers Hyderabad           22
# 634  normal           0          Sunrisers Hyderabad            0
# ...

# %%
df.loc[0:5,['winner','player_of_match']]
# Out:
#                         winner player_of_match
# 0          Sunrisers Hyderabad    Yuvraj Singh
# 1       Rising Pune Supergiant       SPD Smith
# 2        Kolkata Knight Riders         CA Lynn
# 3              Kings XI Punjab      GJ Maxwell
# 4  Royal Challengers Bangalore       KM Jadhav
# 5          Sunrisers Hyderabad     Rashid Khan

# %%
df.loc[0:2]
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
df.iloc[[3,5,7,9]]
# Out:
#    id  season       city        date                        team1  \
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                  team2                  toss_winner toss_decision  result  \
# 3      Kings XI Punjab              Kings XI Punjab         field  normal
# 5  Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 7      Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 9       Mumbai Indians               Mumbai Indians         field  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# 3           0      Kings XI Punjab            0               6
# 5           0  Sunrisers Hyderabad            0               9
# 7           0      Kings XI Punjab            0               8
# ...

# %%
df.iloc[1:5, 2:5]
# Out:
#         city        date                        team1
# 1       Pune  2017-04-06               Mumbai Indians
# 2     Rajkot  2017-04-07                Gujarat Lions
# 3     Indore  2017-04-08       Rising Pune Supergiant
# 4  Bangalore  2017-04-08  Royal Challengers Bangalore

# %%
df["team1"].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants'],
#       dtype=object)

# %%
df.nunique()
# Out:
# id                 636
# season              10
# city                30
# date               450
# team1               14
# team2               14
# toss_winner         14
# toss_decision        2
# result               3
# dl_applied           2
# winner              14
# win_by_runs         86
# win_by_wickets      11
# player_of_match    201
# venue               35
# umpire1             44
# umpire2             45
# umpire3              0
# dtype: int64

# %%
df.isnull()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 631  False   False  False  False  False  False        False          False
# 632  False   False  False  False  False  False        False          False
# 633  False   False  False  False  False  False        False          False
# 634  False   False  False  False  False  False        False          False
# 635  False   False  False  False  False  False        False          False
#
# ...

# %%
df.sort_values(by='date')
# Out:
#     id  season        city        date                        team1  \
# 59  60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 61  62    2008       Delhi  2008-04-19             Rajasthan Royals
# 60  61    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 63  64    2008     Kolkata  2008-04-20              Deccan Chargers
# 62  63    2008      Mumbai  2008-04-20               Mumbai Indians
# ..  ..     ...         ...         ...                          ...
# 54  55    2017       Delhi  2017-05-14  Royal Challengers Bangalore
# 55  56    2017      Mumbai  2017-05-16       Rising Pune Supergiant
# 56  57    2017   Bangalore  2017-05-17          Sunrisers Hyderabad
# 57  58    2017   Bangalore  2017-05-19        Kolkata Knight Riders
# 58  59    2017   Hyderabad  2017-05-21               Mumbai Indians
#
#                           team2                  toss_winner toss_decision  \
# ...

# %%
df.value_counts('winner')
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
df.nlargest(5, 'win_by_runs')
# Out:
#       id  season       city        date                        team1  \
# 43    44    2017      Delhi  2017-05-06               Mumbai Indians
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 59    60    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 556  557    2015  Bangalore  2015-05-06  Royal Challengers Bangalore
# 410  411    2013  Bangalore  2013-04-23  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 43              Delhi Daredevils             Delhi Daredevils         field
# 619                Gujarat Lions                Gujarat Lions         field
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 556              Kings XI Punjab              Kings XI Punjab         field
# 410                Pune Warriors                Pune Warriors         field
#
#      result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.nsmallest(4, 'win_by_runs',keep='first')
# Out:
#    id  season       city        date                   team1  \
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09           Gujarat Lions
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 2           0   Kolkata Knight Riders            0              10
# 3           0         Kings XI Punjab            0               6
# ...

# %%
df1 = df.copy()
df1
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df = pd.read_csv("matches.csv", index_col = 'date')
df.rename(index = {"2017-04-05": "2017-04-13"} ,inplace = True )
df
# Out:
#              id  season       city                        team1  \
# date
# 2017-04-13    1    2017  Hyderabad          Sunrisers Hyderabad
# 2017-04-06    2    2017       Pune               Mumbai Indians
# 2017-04-07    3    2017     Rajkot                Gujarat Lions
# 2017-04-08    4    2017     Indore       Rising Pune Supergiant
# 2017-04-08    5    2017  Bangalore  Royal Challengers Bangalore
# ...         ...     ...        ...                          ...
# 2016-05-22  632    2016     Raipur             Delhi Daredevils
# 2016-05-24  633    2016  Bangalore                Gujarat Lions
# 2016-05-25  634    2016      Delhi          Sunrisers Hyderabad
# 2016-05-27  635    2016      Delhi                Gujarat Lions
# 2016-05-29  636    2016  Bangalore          Sunrisers Hyderabad
#
#                                   team2                  toss_winner  \
# date
# 2017-04-13  Royal Challengers Bangalore  Royal Challengers Bangalore
# ...

# %%
df2 = df1.where(df1["win_by_runs"]  > 30)
df2
# Out:
#       id  season       city        date                team1  \
# 0    1.0  2017.0  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1    NaN     NaN        NaN         NaN                  NaN
# 2    NaN     NaN        NaN         NaN                  NaN
# 3    NaN     NaN        NaN         NaN                  NaN
# 4    NaN     NaN        NaN         NaN                  NaN
# ..   ...     ...        ...         ...                  ...
# 631  NaN     NaN        NaN         NaN                  NaN
# 632  NaN     NaN        NaN         NaN                  NaN
# 633  NaN     NaN        NaN         NaN                  NaN
# 634  NaN     NaN        NaN         NaN                  NaN
# 635  NaN     NaN        NaN         NaN                  NaN
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1                            NaN                          NaN           NaN
# ...

# %%
df.drop('dl_applied',axis='columns')
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
des.corr(method = 'kendall')
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets  \
# id              1.000000  0.444750    0.501745     0.666795        0.868079
# season          0.444750  1.000000   -0.080582     0.113389        0.254588
# dl_applied      0.501745 -0.080582    1.000000     0.852803        0.574427
# win_by_runs     0.666795  0.113389    0.852803     1.000000        0.731310
# win_by_wickets  0.868079  0.254588    0.574427     0.731310        1.000000
# umpire3              NaN       NaN         NaN          NaN             NaN
#
#                 umpire3
# id                  NaN
# season              NaN
# dl_applied          NaN
# win_by_runs         NaN
# win_by_wickets      NaN
# umpire3             1.0

# %%
des.corr(method = 'pearson')
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets  \
# id              1.000000 -0.066313    0.520994     0.649713        0.532227
# season         -0.066313  1.000000   -0.480320    -0.459456       -0.479359
# dl_applied      0.520994 -0.480320    1.000000     0.975602        0.999905
# win_by_runs     0.649713 -0.459456    0.975602     1.000000        0.977832
# win_by_wickets  0.532227 -0.479359    0.999905     0.977832        1.000000
# umpire3              NaN       NaN         NaN          NaN             NaN
#
#                 umpire3
# id                  NaN
# season              NaN
# dl_applied          NaN
# win_by_runs         NaN
# win_by_wickets      NaN
# umpire3             NaN

# %%
df = pd.read_csv("matches.csv")
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
new = pd.read_csv("matches.csv") #stpe 1 - read the CSV
new["Null Column"] = None
len(df.dtypes)
# Out:
# 18

# %%
len(new.dtypes) #step 2 - print the length if new dataframe
# Out:
# 19

# %%
new.dropna(axis=1, how='all', inplace= True) #step 3 - drop the Columns with NaN values

# %%
len(new.dtypes)  #step 4 - before length of new df is 19 now it is 17.So 2 columns of Null values reomved
# Out:
# 17

# %%
len(df.dtypes)
# Out:
# 18

# %%
print(len())

# %%
import pandas as pd

df = pd.read_csv("matches.csv")
new = pd.read_csv("matches.csv")

new["Null_column"] = None
print(len(new.dtypes))
print("Before the drop",len(new.dtypes)-len(df.dtypes))

column = list(new)
print(*column)
new.dropna(axis=1, how='all', inplace= True)

column = list(new)
print(*column)
# Out:
# 19
# Before the drop 1
# id season city date team1 team2 toss_winner toss_decision result dl_applied winner win_by_runs win_by_wickets player_of_match venue umpire1 umpire2 umpire3 Null_column
# id season city date team1 team2 toss_winner toss_decision result dl_applied winner win_by_runs win_by_wickets player_of_match venue umpire1 umpire2

# %%
import pandas as pd

df1 = pd.read_csv("matches.csv")
df1["umpire3"].fillna("Umpire Not Assigned", inplace = True)
df1
# Out:
# C:\Users\Hari Haran\AppData\Local\Temp\ipykernel_12392\3527225798.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Umpire Not Assigned' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df1["umpire3"].fillna("Umpire Not Assigned", inplace = True)
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# ...
